# %% [markdown]
# ## HOUSE PRICE PREDICTION

# %% [markdown]
# Using a data name "House Price Prediction" downloaded on kaggle to predict the price of house using some factors align with it>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_set=pd.read_csv('houseprice.csv')

# %%
data_set.head(10)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data_set.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# PLot of living room square fit against price
plt.scatter(data_set['sqft_living'], data_set['price'])

# %%
# define the input x and the output/prediction (y)
y = data_set['price']
x = data_set.drop(['date', 'price', 'street', 'city', 'statezip','country'], axis=1)   #axis give directive to drop column not row

# %%
# we have to train the data on a regression model

from sklearn.linear_model import LinearRegression
regres = LinearRegression()

# %%
# sppliting the data into training set and testing set

from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
#getting the shape of the x train and y train
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3680, 12)
# (3680,)
# (920, 12)
# (920,)

# %%
# we need to train the data
regres.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
# we also need to test model against the data after the data is been trained 
regres.score(x_test, y_test)
# Out:
# 0.05613734541681048

# %% [markdown]
# Basicallly 5.6% of the test signify that the independent variables which are (Bathroom, Living Rohadom, floor square metter etc) had a very low prediction on the house pprice.
#
# Because the location in this data set its not a variable but string and it was drop in other to get the regression analysis done. in the future analysis i will as well assign a variable to the strings variable in other to get the extent at which the price of house could be predicted by the factors aligned with it.
